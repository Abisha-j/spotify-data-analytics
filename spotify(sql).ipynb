# %%
# %load_ext sql
# %sql mysql+mysqlconnector://root:2001@localhost/

# %%
# %%sql
# show databases;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/
# 6 rows affected.
# [('information_schema',),
#  ('mysql',),
#  ('performance_schema',),
#  ('sales',),
#  ('spotify_db',),
#  ('sys',)]

# %%
# %%sql
# drop database test;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/
# (mysql.connector.errors.DatabaseError) 1008 (HY000): Can't drop database 'test'; database doesn't exist
# [SQL: drop database test;]
# (Background on this error at: https://sqlalche.me/e/20/4xp6)

# %%
# %%sql
# create database spotify_db;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/
# (mysql.connector.errors.DatabaseError) 1007 (HY000): Can't create database 'spotify_db'; database exists
# [SQL: create database spotify_db;]
# (Background on this error at: https://sqlalche.me/e/20/4xp6)

# %%
# %%sql
#
# use spotify_db;
# CREATE TABLE IF NOT EXISTS spotify_tracks (
#     id INT AUTO_INCREMENT PRIMARY KEY,
#     track_name VARCHAR(255),
#     artist VARCHAR(255),
#     album VARCHAR(255),
#     popularity INT,
#     duration_minutes FLOAT
# )
# Out:
#  * mysql+mysqlconnector://root:***@localhost/
# 0 rows affected.
# 0 rows affected.
# []

# %%
# %%sql
# select * from spotify_tracks;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/
# 9 rows affected.
# [(1, 'Mr. Brightside', 'The Killers', 'Hot Fuss', 63, 3.70333),
#  (2, 'Time is Running Out', 'Muse', 'Absolution', 3, 3.95065),
#  (3, 'Uprising', 'Muse', 'The Resistance', 78, 5.08067),
#  (4, 'Despacito', 'Luis Fonsi', 'VIDA', 81, 3.82267),
#  (5, 'Mr. Brightside', 'The Killers', 'Hot Fuss', 7, 3.70125),
#  (6, 'Lover', 'Taylor Swift', 'Lover', 84, 3.68843),
#  (7, 'Shape of You', 'Ed Sheeran', '÷ (Deluxe)', 89, 3.8952),
#  (8, 'Every Breath You Take', 'The Police', 'Synchronicity (Remastered 2003)', 94, 4.232),
#  (9, 'Prelude for Piano No. 11 in F-Sharp Minor', 'Eduard Abramyan', 'Abramyan: Preludes – Rachmaninoff: Sonata No. 2 in B-Flat Minor, Op. 36 – Babadjanyan: Capriccio, Improvisation, Folksong, Elegy, Poem', 28, 4.13822)]

# %%
# %%sql
# SELECT track_name, artist, album, popularity
# FROM spotify_tracks
# ORDER BY popularity DESC
# LIMIT 1;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/
# 1 rows affected.
# [('Every Breath You Take', 'The Police', 'Synchronicity (Remastered 2003)', 94)]

# %%
# %%sql
# SELECT AVG(popularity) AS average_popularity
# FROM spotify_tracks;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/
# 1 rows affected.
# [(Decimal('58.5556'),)]

# %%
# %%sql
# SELECT track_name, artist, duration_minutes
# FROM spotify_tracks
# WHERE duration_minutes > 4.0;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/
# 3 rows affected.
# [('Uprising', 'Muse', 5.08067),
#  ('Every Breath You Take', 'The Police', 4.232),
#  ('Prelude for Piano No. 11 in F-Sharp Minor', 'Eduard Abramyan', 4.13822)]

# %%
# %%sql
# SELECT
#     CASE
#         WHEN popularity >= 80 THEN 'Very Popular'
#         WHEN popularity >= 50 THEN 'Popular'
#         ELSE 'Less Popular'
#     END AS popularity_range,
#     COUNT(*) AS track_count
# FROM spotify_tracks
# GROUP BY popularity_range;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/
# 3 rows affected.
# [('Popular', 2), ('Less Popular', 3), ('Very Popular', 4)]
